# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from LineDetection import *

# %%
image=cv2.imread('YUSVM.png')

# %%
Edges = Canny(image)
HoughAccumlator, Rhos, Thetas = HoughLinesAccumlator(Edges)
Indicies, HoughAccumlator = GetPeaks(HoughAccumlator, 24, NeighborhoodSize=20)
# Out:
# 142740
# (793, 0)
# 77760
# (432, 0)
# 87300
# (485, 0)
# 103860
# (577, 0)
# 180632
# (1003, 92)
# 205649
# (1142, 89)
# 213568
# (1186, 88)
# 197550
# (1097, 90)
# 221307
# (1229, 87)
# 188731
# (1048, 91)
# 69120
# (384, 0)
# 233366
# (1296, 86)
# 111780
# (621, 0)
# 156695
# (870, 95)
# 229946
# (1277, 86)
# 173433
# (963, 93)
# 165875
# (921, 95)
# 95400
# (530, 0)
# 46261
# (257, 1)
# 59220
# (329, 0)
# 174059
# (966, 179)
# 199259
# (1106, 179)
# 51121
# (284, 1)
# 120060
# (667, 0)

# %%
PlotHoughAcculmator(HoughAccumlator)
# Out:
# D:\SBME\Computer Vision\Tasks\Computer-Vision-Task-2\LineDetection.py:24: MatplotlibDeprecationWarning:
# The set_window_title function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use manager.set_window_title or GUI-specific methods instead.
#   fig.canvas.set_window_title(plot_title)

# %%
DrawLines(image, Indicies, Rhos, Thetas)
plt.imshow(image)
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
from CircleDetection import *

# %%
image=cv2.imread('coins.jpg')
circles = DetectCircles(image, Threshold=10, Region=25, Raduis=[20, 50])
image=DisplayCircles(circles,image)
plt.imshow(image)
plt.show()
