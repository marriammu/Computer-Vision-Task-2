# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from LineDetection import *
from Utilities import *
from snakes_show import *

# %%
image=cv2.imread('YUSVM.png')

# %% [markdown]
# ### Lines

# %%
Edges = Canny(image)
HoughAccumlator, Rhos, Thetas = HoughLinesAccumlator(Edges)
Indicies, HoughAccumlator = GetPeaks(HoughAccumlator, 24, NeighborhoodSize=20)

# %%
PlotHoughAcculmator(HoughAccumlator)

# %%
DrawLines(image, Indicies, Rhos, Thetas)
plt.imshow(image)
plt.show()

# %% [markdown]
# ### Circles

# %%
import cv2
import matplotlib.pyplot as plt
from CircleDetection import *

# %%
image=cv2.imread('coins.jpg')
circles = DetectCircles(image, Threshold=10, Region=25, Raduis=[20, 50])

# %%
image=DisplayCircles(circles,image)
plt.imshow(image)
plt.show()

# %% [markdown]
# ### Active Contour

# %%
image1 = cv2.imread( "image_ex.png", cv2.IMREAD_COLOR )
image2 = cv2.imread( "example.jpg", cv2.IMREAD_COLOR )
image3 = cv2.imread( "example2.jpg", cv2.IMREAD_COLOR )
image4 = cv2.imread( "example4.jpg", cv2.IMREAD_COLOR )

# %%
snakes(image1,7,10,3)
# Out:
# E:\cv_tasks\task2\Computer-Vision-Task-2\Utilities.py:192: RuntimeWarning: overflow encountered in ulong_scalars
#   sum_ = int_img[y1, x1]-int_img[y0, x1]-int_img[y1, x0]+int_img[y0, x0]
# C:\Users\DELL\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:87: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# area= 8832.0
# ............
# perimeter= 350.8123389813855

# %%
snakes(image2,15,10,7)
# Out:
# area= 88389.0
# ............
# perimeter= 1170.7881540002618

# %%
snakes(image3,20,7,5)
# Out:
# area= 34700.0
# ............
# perimeter= 758.5859880467784

# %%
snakes(image4,30,20,5)
# Out:
# area= 7695.5
# ............
# perimeter= 362.1911008675991
